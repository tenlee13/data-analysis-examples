# %%
import pandas as pd

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=(4, 16, 19, 27, 28, 33))

# %%
df.fillna(' ', inplace = True)

# %%
df.rename(columns={4:"Organization", 27:"Name", 28:"Activity", 33:"Director", 16:"Adress", 19:"Telephone"}, inplace=True)

# %%
df
# Out:
#                                              Organization  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df
# Out:
#                                              Organization  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df.loc[10]
# Out:
# Organization    Общество с ограниченной ответственностью "Мана...
# Adress
# Telephone                                           03222 7-17-13
# Name                                               Шафиев Юлчувай
# Activity        Прочие строительно-монтажные работы, не включе...
# Director                                           Шафиев Юлчувай
# Name: 10, dtype: object

# %%
df.loc[df['Adress'] == 'Комсомольская']
# Out:
#                                              Organization         Adress  \
# 9             РО "Церковь Евангельских Христян-баптистов"  Комсомольская
# 304                      Кыргызско-Турецкое ООО " РУКИЯ "  Комсомольская
# 1215                                     ОсОО "Ак-Жолтой"  Комсомольская
# 2696           Общественный благотворительный фонд "Хаят"  Комсомольская
# 2819    Общество с ограниченной ответственностью "Воен...  Комсомольская
# 2824    Общество с ограниченной ответственностью " про...  Комсомольская
# 3676    Общество с ограниченной ответственностью "Обув...  Комсомольская
# 4909    Учреждение "Микрокредитное агентство "Актилек-...  Комсомольская
# 6174    Учреждение "Жети-Огузская районная стоматологи...  Комсомольская
# 12815             Закрытое акционерное общество "Сут-Кол"  Комсомольская
# 14896   Общество с ограниченной ответственностью Охран...  Комсомольская
# 17675                   Общественный фонд "Алинур тилеги"  Комсомольская
# ...

# %%
df.loc[df['Director'].str.contains('Александр')]
# Out:
#                                              Organization  \
# 17                                             ОсОО "ЛЕП"
# 25      Совместное Кыргызско-Немецкое общество с огран...
# 59                                          АОЗТ "ШИРКОН"
# 74             Общественный Фонд имени Булата Минжилкиева
# 112                                         ОсОО "Фарсаж"
# 116                                         ОсОО "Каймак"
# 120     Совместный Кыргызско-Казахский благотворительн...
# 144     Кыргызско-Казахское Общество с ограниченной от...
# 150                                           ООО "Гонец"
# 160              Церковь Евангельских-Христиан Баптистов.
# 176     Совместное Кыргызско-Украинского ОсОО "Сложно-...
# 187                                            ООО "SALE"
# 203                                    ООО "Чон-Жеты-Суу"
# 258     Общественное правовое объединение "Гражданское...
# 278     Общественное объединение "Бишкекский комитет г...
# ...

# %%
df.loc[(df['Adress'].str.contains('Комсомольская')) & (df['Name'].str.contains('Александр'))]
# Out:
#                                              Organization             Adress  \
# 2824    Общество с ограниченной ответственностью " про...      Комсомольская
# 39145                                        ОБФ "Геонем"      Комсомольская
# 70090   Филиал Общества с ограниченной ответственность...  ул. Комсомольская
# 100227  Общество с ограниченной ответственностью "ТРАН...  ул. Комсомольская
# 105143  Объединение юридических лиц Союз "Казаки Семир...   ул.Комсомольская
#
#          Telephone                             Name  \
# 2824                      Цой Александр  Николаевич
# 39145                   Сметанин Александр Иванович
# 70090   0555004645  Паранин Станислав Александрович
# 100227               Янушевский Александр Сергеевич
# 105143  0555123137        Зуев Александр Михайлович
#
#                                                  Activity  \
# 2824       Оказание услуг физическим и юридическим лицам.
# 39145
# 70090   Деятельность прочего пассажирского наземного т...
# ...

# %%
df.loc[df['Director'].str.contains('Мчедлишвили')]
# Out:
#                                              Organization       Adress  \
# 5076    Общество с ограниченной ответственностью "Гео ...
# 26261    Общество с ограниченной ответственностью "Имэди"
# 33231   Общество с ограниченной ответственностью "Океа...
# 36879   Общество с ограниченной ответственностью "Иверия"  ул. Примова
# 54375   Общество с ограниченной ответственностью "Фарм...  ул. Матыева
# 66056   Общество с ограниченной ответственностью "Гео ...
# 66117   Общество с ограниченной ответственностью "Иверия"
# 125041  Общество с ограниченной ответственностью "Гео ...
#
#             Telephone                          Name  \
# 5076    (03222) 75656   Мчедлишвили Гоча Зурабович
# 26261                  Мчедлишвилли Гоча Зурабович
# 33231     03222 62680  Мчедлишвили Зураб Рафиелович
# 36879      0551055014  Мчедлишвили Зураб Рафиелович
# 54375      0555920930    Дюйшекеев Тилек Омурбаевич
# 66056   (03222) 75656   Мчедлишвили Гоча Зурабович
# ...

# %%
df.loc[(df['Activity'].str.contains('Строительство')) & (df['Telephone'].str.contains('432'))]
# Out:
#                                              Organization              Adress  \
# 20582   Общество с ограниченной ответственностью "Нект...
# 56450   Общество с ограниченной ответственностью "Пром...           ул.Достук
# 59419   Общество с ограниченной ответственностью "Теги...            ул.Жапар
# 63409   Общество с ограниченной ответственностью "Байзат"       Салиева 40г-2
# 69270   Общество с ограниченной ответственностью "Альф...      ул.Логвиненко
# 71212   Общество с ограниченной ответственностью "ВРЕМ...
# 76404   Филиал Общества с ограниченной ответственность...     ул. Депутатская
# 80891    Общество с ограниченной ответственностью "ЖАКИН"      ул.Тыныстанова
# 86107   Общество с ограниченной ответственностью "Мара...          ул. Алиева
# 89052   Общество с ограниченной ответственностью "БАЙН...        участок 1667
# 95065   Общество с ограниченной ответственностью "Паде...  ул. С. Атагелдиева
# ...

# %%
df.loc[(df['Organization'].str.contains(' ')) & (df['Director'].str.contains('Александр')) &(df['Adress'].str.contains('Комсомольская'))]
# Out:
#                                              Organization             Adress  \
# 39145                                        ОБФ "Геонем"      Комсомольская
# 100227  Общество с ограниченной ответственностью "ТРАН...  ул. Комсомольская
#
#        Telephone                            Name                  Activity  \
# 39145                Сметанин Александр Иванович
# 100227            Янушевский Александр Сергеевич  Оптовая торговля одеждой
#
#                                                  Director
# 39145   Госплемптицзавод Иссык-Атинского района, ОсОО ...
# 100227                     Янушевский Александр Сергеевич
